# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
from isodate import parse_duration

# %%
api_key = 'AIzaSyDYkZY38Jotmhr1nxq3H8ZK8TRU3i_U3Bg'
youtube = build('youtube', 'v3', developerKey=api_key)
channel_ids ='UCk3JZr7eS3pg5AGEvBdEvFg'

# %%
def channel_info(channel_ids):
    channels = []
    request = youtube.channels().list(part='snippet,statistics,contentDetails',id = channel_ids)
    response = request.execute()
    data = dict(
          Channel_Name = response['items'][0]['snippet']['title'],
          Channel_Id = response['items'][0]['id'],
          Channel_Description = response['items'][0]['snippet']['description'],
          Channel_Views = response['items'][0]['statistics']['viewCount'],
          Subscription_Count = response['items'][0]['statistics']['subscriberCount'] ,
          Playlist_Id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
          Playlist_Name = response['items'][0]['snippet']['title'])
    channels.append(data)
    return channels

# %%
channel = channel_info(channel_ids)

# %%
df = pd.DataFrame(channel)
df
# Out:
#               Channel_Name                Channel_Id  \
# 0  Village Cooking Channel  UCk3JZr7eS3pg5AGEvBdEvFg
#
#                                  Channel_Description Channel_Views  \
# 0  Village grandpa cooking traditional village fo...    6307595437
#
#   Subscription_Count               Playlist_Id            Playlist_Name
# 0           22600000  UUk3JZr7eS3pg5AGEvBdEvFg  Village Cooking Channel

# %%
def playlist(channel_id):
    playlists = []
    next_page_token = None
    while True:
        request = youtube.playlists().list(
            part='snippet,contentDetails', 
            channelId= channel_id ,
            maxResults=50,
            pageToken = next_page_token
            )
        response = request.execute()
            #print(response)
        for playlist in response.get('items',[]):
            data = dict(
                channel_id = playlist['snippet']['channelId'],
                playlist_id = playlist['id'],
                playlist_name = playlist['snippet']['title']
                )
            playlists.append(data)
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break
            
    return playlists

# %%
#channel_ids = ['UCk3JZr7eS3pg5AGEvBdEvFg','UCduIoIMfD8tT3KoU0-zBRgQ']
play = playlist('UCk3JZr7eS3pg5AGEvBdEvFg')

# %%
df = pd.DataFrame(play)

# %%
df
# Out:
#                   channel_id                         playlist_id  \
# 0   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8VqgRI8w9vZhZDk1yJrMoY
# 1   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk9SpblNk8ziBlzPiAvU5Ux_
# 2   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_lExzFmVgY7xwSem-241nU
# 3   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-LCfUGfScvoBXs_n4U1vlr
# 4   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-DFlXSD_0YPn8a9kCAYi7q
# 5   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_UVNVJxLsv_j-PxKAiHYal
# 6   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8gerVuoUJzJUMeRfcVD8zX
# 7   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8BlX0adstQ442qbw1O3XbC
# 8   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk92GFZmNvRoYkCjw85zmoCw
# 9   UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_cAsbee-TDdYys3yl36EE7
# 10  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_xOA45Uc32e9RpOrwcKFcG
# 11  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8gi9EXxwH-ioBMajeyt9V8
# 12  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_Zg2c_ZZBZCMMSZabqqxfT
# 13  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-uProi-h6NdseahVRJEJvn
# 14  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_BAYOHY2lrnBbC1xTRRvsx
# 15  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8GN_QPYcVREzD-i9Lrw61S
# 16  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-JL4R9qtvd9AG9OCj9gMgp
# 17  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_geZx32EDK5NfIu32Ul_8O
# 18  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk91X6La8aHOM7kyFJhdtEzq
# 19  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-lRfQ99YWc0Al0SY7v1ksV
# 20  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8fX5bYnjwxHZr5v8C_0T-R
# 21  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-FecnY2SVsu1asnYefcaqH
# 22  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk9kLCF9p70BVKcJhrlm4HbW
# 23  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-mWRryD98PIDf_OUb0eG-C
# 24  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-JAAnAVdpujSZB8QSTo8ro
# 25  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk9ddr6yKRghJfavKPU-n0tT
# 26  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8aId5lp8gdnh-jz0iu1WzX
# 27  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-MLvlRK0kOy-MgFu16Gi6k
# 28  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk_PcT5U6Bts-fQ7nmUM3mFQ
# 29  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-XgCfwG7-4Qa3BuZiWFhRh
# 30  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk9m_66EXOn58Cj4DUXmj10v
# 31  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-UOnZxhoRN279qAhE6kk7b
# 32  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk92mbPKX2AXnwiv35uq1CfP
# 33  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8RrehRJfZWniJUsnSBj-TR
# 34  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-LZNQh2WFFr9zNmb_MZQcr
# 35  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk97SP4Met9SJ6mQqsK71-VG
# 36  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-fCWNu5tNtD2P-LXjC0KZ2
# 37  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk96lkKvjvpBKGfIdKE2Izwk
# 38  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-MYhABlletjHa6oNFPpOtS
# 39  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk8Xr69IH1yabcCU__knrUsc
# 40  UCk3JZr7eS3pg5AGEvBdEvFg  PL-NHxGqGGGk-3nur5KV2DXG4A8SkO2JtU
#
#                                      playlist_name
# 0                                           Shorts
# 1                                     chinese food
# 2                             Play Button Unboxing
# 3                                    YouTube Award
# 4                                   Healthy Drinks
# 5                                      Fruit Juice
# 6                                     Soup Recipes
# 7                                  Chicken Recipes
# 8                              chicken legs recipe
# 9                             Goat's Parts Recipes
# 10                                   Bones Recipes
# 11                          Village Cooking Videos
# 12                          dessert recipes indian
# 13                                 dessert recipes
# 14                            diwali sweets recipe
# 15                            Tasty Dessert Recipe
# 16                                   snack recipes
# 17                              easy snack recipes
# 18                      easy crunchy snack recipes
# 19                      easy crispy snacks recipes
# 20                          Quick and Easy Recipes
# 21                South Indian Street Food Recipes
# 22                                American Recipes
# 23                               Easy Snack Recipe
# 24                                  Quail recipies
# 25                              Cooking and Eating
# 26                            Punjabi Food Recipes
# 27                                    Fish recipes
# 28                                  Biryani Recipe
# 29                         Grandpa Cooking Biryani
# 30                               Biriyani Recipies
# 31                                          Mutton
# 32                                  Mutton Recipes
# 33         Indian Street Food | Cooking By Grandpa
# 34                Indian cuisine | Grandpa Cooking
# 35   vegan recipes | Grandpa Cooking vegan recipes
# 36  Indian Vegetarian Recipes | Cooking By Grandpa
# 37                              Vegetarian Recipes
# 38                                         Non Veg
# 39                                         Seafood
# 40                                             Egg

# %%
from pprint import pprint
def video_info(channel_id):
    request = youtube.channels().list(id = channel_id,
                                   part = 'contentDetails')
    response = request.execute()
    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    #pprint(playlist_id)
    videos_details = []
    videos_id = []
    next_page_token = None
    
    while True:
        video_id_request = youtube.playlistItems().list(playlistId = playlist_id,
                                              part = 'snippet',
                                              maxResults = 50,
                                              pageToken = next_page_token)
        video_id_response = video_id_request.execute()
        for item in video_id_response['items']:
            video_id = item['snippet']['resourceId']['videoId']
            
            
            video_request = youtube.videos().list(
                part='snippet,contentDetails,statistics',
                id=video_id)
            video_response = video_request.execute()
            view_count= int(video_response['items'][0]['statistics']['viewCount'])
            like_count = int(video_response['items'][0]['statistics']['likeCount'])
            
            data = dict(video_id =  video_response['items'][0]['id'],
                        channel_id =video_response['items'][0]['snippet']['channelId'],
                        video_name = video_response['items'][0]['snippet']['title'],
                        video_description = video_response['items'][0]['snippet']['description'],
                        #video_tags = video_response['items'][0]['snippet']['tags'],
                        video_duration = int(parse_duration(video_response['items'][0]['contentDetails']['duration']).total_seconds()),
                        publishedat = datetime.strptime(video_response['items'][0]['snippet']['publishedAt'],"%Y-%m-%dT%H:%M:%SZ"),
                        view_count= int(video_response['items'][0]['statistics']['viewCount']),
                        like_count = int(video_response['items'][0]['statistics']['likeCount']),
                        dislike_count = (view_count)-(like_count),
                        favorite_count = int(video_response['items'][0]['statistics']['favoriteCount']),
                        comment_count = int(video_response['items'][0]['statistics']['commentCount']),
                        thumbnail = video_response['items'][0]['snippet']['thumbnails']['default']['url'],
                        caption = video_response['items'][0]['contentDetails']['caption']
                       )
            videos_details.append(data)
        next_page_token = video_id_response.get('nextPageToken')
        if next_page_token is None:
            break
            
    return videos_details

# %%
 video = video_info('UCk3JZr7eS3pg5AGEvBdEvFg')

# %%
df = pd.DataFrame(video)
df
# Out:
#         video_id                channel_id  \
# 0    r3XBGY6sQ1Q  UCk3JZr7eS3pg5AGEvBdEvFg
# 1    qnozeCkyzzw  UCk3JZr7eS3pg5AGEvBdEvFg
# 2    BsLQx3tbhnI  UCk3JZr7eS3pg5AGEvBdEvFg
# 3    0n47msSQllA  UCk3JZr7eS3pg5AGEvBdEvFg
# 4    1QeAcyWz198  UCk3JZr7eS3pg5AGEvBdEvFg
# ..           ...                       ...
# 220  VJwXGCdt5gk  UCk3JZr7eS3pg5AGEvBdEvFg
# 221  Mq7wKfqRUCA  UCk3JZr7eS3pg5AGEvBdEvFg
# 222  UXkV4CZtY94  UCk3JZr7eS3pg5AGEvBdEvFg
# 223  4iL5_cvRAkk  UCk3JZr7eS3pg5AGEvBdEvFg
# 224  NcE0XMuMWIc  UCk3JZr7eS3pg5AGEvBdEvFg
#
#                                             video_name  \
# 0    CHICKEN MOMOS | Steamed Momos Recipe Cooking i...
# 1    CHICKEN OMELETTE | Huge Eggs With Chicken Meat...
# 2    FRUIT JELLY CAKE | Colorful Healthy Fruit Jell...
# 3    200 Pounds BIG TUNA FISH | Tuna Fish Cutting a...
# 4    SOAN PAPDI | Mega Ghee Soan Papdi Making in In...
# ..                                                 ...
# 220  Pepper Chicken | Cooking and Eating | Village ...
# 221  KING of CRAB Gravy Prepared By Grandpa | NANDU...
# 222  CHICKEN LEGS | Grandpa cooking chicken legs fr...
# 223  Pathakattai Fish Catching | Cooking | Fishing ...
# 224  Eesal | Cooking Eating Winged TERMITES | Healt...
#
#                                      video_description  video_duration  \
# 0    Today in our village, we cook delicious steame...             483
# 1    Today in our village, we cook a huge quantity ...             524
# 2    Today, in our village, we make colorful fruit ...             577
# 3    Today in our village, we cook big Tuna fish to...             589
# 4    Today in our village, we make mega Soan Papdi ...             481
# ..                                                 ...             ...
# 220  My grandpa cooking Chettinad pepper chicken re...             659
# 221  Delicious crab Gravy recipe prepared by my gra...             631
# 222  I want to eat all the chicken legs cooked by g...             719
# 223  In my village, we catching a lot of fishes in ...             661
# 224  Eesal | Cooking Eating Winged TERMITES | Healt...             635
#
#             publishedat  view_count  like_count  dislike_count  \
# 0   2023-09-22 14:10:54     1776586       95682        1680904
# 1   2023-09-05 14:12:16    31101108      403559       30697549
# 2   2023-08-27 14:04:36    17686837      273865       17412972
# 3   2023-08-16 14:39:05    28314849      336234       27978615
# 4   2023-08-06 14:21:41     8447530      182505        8265025
# ..                  ...         ...         ...            ...
# 220 2018-12-20 08:30:56    18690785      246424       18444361
# 221 2018-12-11 14:16:04    11603777      122448       11481329
# 222 2018-12-03 15:37:38    21382768      363962       21018806
# 223 2018-10-24 13:16:44     6858824      108612        6750212
# 224 2018-10-09 14:42:33     7661047      150650        7510397
#
#      favorite_count  comment_count  \
# 0                 0           2191
# 1                 0           7583
# 2                 0           4715
# 3                 0           5050
# 4                 0           2965
# ..              ...            ...
# 220               0           3540
# 221               0           2738
# 222               0           6730
# 223               0           1854
# 224               0           9116
#
#                                           thumbnail caption
# 0    https://i.ytimg.com/vi/r3XBGY6sQ1Q/default.jpg   false
# 1    https://i.ytimg.com/vi/qnozeCkyzzw/default.jpg   false
# 2    https://i.ytimg.com/vi/BsLQx3tbhnI/default.jpg   false
# 3    https://i.ytimg.com/vi/0n47msSQllA/default.jpg   false
# 4    https://i.ytimg.com/vi/1QeAcyWz198/default.jpg   false
# ..                                              ...     ...
# 220  https://i.ytimg.com/vi/VJwXGCdt5gk/default.jpg   false
# 221  https://i.ytimg.com/vi/Mq7wKfqRUCA/default.jpg   false
# 222  https://i.ytimg.com/vi/UXkV4CZtY94/default.jpg   false
# 223  https://i.ytimg.com/vi/4iL5_cvRAkk/default.jpg   false
# 224  https://i.ytimg.com/vi/NcE0XMuMWIc/default.jpg   false
#
# [225 rows x 13 columns]

# %%
def comment_info(ids):
    comments = []
    for i in ids:
        try:
            
            comments_request = youtube.commentThreads().list(
                        part='snippet',
                        videoId=i,
                        textFormat='plainText',
                        maxResults=100)
            comments_response = comments_request.execute()
            for item in comments_response['items']:
                data = dict(comment_id = item['id'],
                            video_id = item['snippet']['videoId'],
                            comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay'],
                            comment_author = item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            comment_publishedat =item['snippet']['topLevelComment']['snippet']['publishedAt'])
                comments.append(data) 
        except:
            pass
              
    
    return comments

# %%
comments = comment_info('qnozeCkyzzw')

# %%
df =pd.DataFrame(comments)
df
# Out:
#                    comment_id     video_id  \
# 0  UgxgoaY2WtuYjpxW9S54AaABAg  qnozeCkyzzw
# 1  Ugz9bMsJ1AHqV81gfBV4AaABAg  qnozeCkyzzw
# 2  UgxvS0zZb_dLH2P1eQF4AaABAg  qnozeCkyzzw
# 3  UgxILtKZ7Lq4B7mx8_94AaABAg  qnozeCkyzzw
# 4  UgwqPP0A2FiX5sEjlbx4AaABAg  qnozeCkyzzw
#
#                                         comment_text         comment_author  \
# 0       👍GOOD JOB\n FOR HELPING POOR,S TO EAT FOOD🙏🏼              STUPID 01
# 1                                               🤮🤮🤮🤮        iam_evaluna MVP
# 2                                     Wow super  ❤❤❤  KAPANG RUM PRODUCTION
# 3                                           Yummmy ❤                    WJ7
# 4  Ungala contact pannanum...please na ....oru mu...         PapparaMuttaii
#
#     comment_publishedat
# 0  2023-09-21T12:06:37Z
# 1  2023-09-21T11:56:11Z
# 2  2023-09-21T11:54:09Z
# 3  2023-09-21T11:48:47Z
# 4  2023-09-21T11:35:10Z

# %%
def main(channel_id):
    channel = channel_info(channel_id)
    playlists = playlist(channel_id)
    videos = video_info(channel_id)
    v_ids = []
    
    for item in videos:
        v_ids.append(item['video_id'])
    comment_details = comment_info(v_ids)
    data = {
        'channel_details': channel,
        'channel_playlists': playlists,
        'video_details': videos,
        'comment_details': comment_details
       }
    
    return data

# %%
data=main('UCk3JZr7eS3pg5AGEvBdEvFg')

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["YTH"]
mycol = mydb["channel_data"]

# %%
mycol.insert_one(data)
